# %% [markdown]
# ### Created by Cosmic Black
#
# #### This notebook is studied from <a href="https://www.kaggle.com/code/ksevta/ps4e2-xgb-lgbm-0-92#Feature-Engineering-&-Processing">PS4E2: XGB / LGBM | 0.92+</a>. If you think my notebook is useful, don't forget to share it with all.

# %% [markdown]
# ## Import necessary libraries

# %%
#necessary
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import random
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Config

# %%
#config
class Config():
    origin_path="/kaggle/input/obesity-or-cvd-risk-classifyregressorcluster/ObesityDataSet.csv"
    train_path='/kaggle/input/playground-series-s4e2/train.csv'
    test_path='/kaggle/input/playground-series-s4e2/test.csv'
    submission_path='/kaggle/input/playground-series-s4e2/sample_submission.csv'
    seed=2024
    num_folds=10
    TARGET_NAME ='NObeyesdad'

# %% [markdown]
# ## preprocessor

# %%
class Preprocessor:
    def __init__(self,train_path=None,origin_path=None,test_path=None,TARGET_NAME ='target',seed=2024):
        self.seed=seed
        
        np.random.seed(self.seed)
        random.seed(self.seed)
        
        self.TARGET_NAME=TARGET_NAME 
        
        if train_path!=None:
            self.train_df=pd.read_csv(train_path)
            self.train_df.drop(['id'],axis=1,inplace=True)
        else:
            assert 0#assert 0==1?
        
        if origin_path!=None:
            origin_df=pd.read_csv(origin_path)
            print(f"len(origin_df):{len(origin_df)}")
            
            self.train_df=pd.concat((self.train_df,origin_df),axis=0)
            print(f"len(self.train_df):{len(self.train_df)}")
        self.train_df.fillna(method="ffill",inplace=True)
        self.train_df=self.train_df.drop_duplicates()
        print(f"len(self.train_df):{len(self.train_df)}")
            
        if test_path!=None:
            self.test_df=pd.read_csv(test_path)
            self.test_df.drop(['id'],axis=1,inplace=True)
            self.test_df.fillna(method="ffill",inplace=True)
        else:
            assert 0#assert 0==1?
        
        self.num_cols=[]
        
        self.cat_cols=[]
        
        self.str_cols=[]
        for col in self.train_df.columns:
            if (self.train_df[col].dtype!='float') and (col!=self.TARGET_NAME) and (self.train_df[col].nunique()<50):
                self.cat_cols.append(col)
            elif (self.train_df[col].dtype=='float') and (col!=self.TARGET_NAME):
                self.num_cols.append(col)
            elif (col!=self.TARGET_NAME):
                self.str_cols.append(col)
        print(f"num_cols:{self.num_cols}.\ncat_cols:{self.cat_cols}.\nstr_cols:{self.str_cols} ")
        
    
    def pearson_corr(self,x1,x2):
        #x1,x2 np.array
        eps=1e-15
        mean_x1=np.mean(x1)
        mean_x2=np.mean(x2)
        std_x1=np.std(x1)
        std_x2=np.std(x2)
        pearson=np.mean((x1-mean_x1)*(x2-mean_x2))/(std_x1*std_x2+eps)
        return pearson
    
    
    def EDA(self,):
        print("num_cols VS cat_cols:")
        for num_col in self.num_cols:
            for cat_col in self.cat_cols:
                unique_value=self.train_df[cat_col].unique()
                for value in unique_value:
                    tmp_df=self.train_df[self.train_df[cat_col]==value]
                    print(f"{cat_col}=={value}:mean_{num_col}=={tmp_df[num_col].mean()}")
                print("-"*50)
            print()
        print("num_cols VS num_cols:")
        for i in range(len(self.num_cols)):
            for j in range(i+1,len(self.num_cols)):
                x1=self.train_df[self.num_cols[i]].values
                x2=self.train_df[self.num_cols[j]].values
                if abs(self.pearson_corr(x1,x2))>0.9:
                    print(f"{self.num_cols[i]} and {self.num_cols[j]} have strong linear correlation.")
                    
        
        if self.train_df[self.TARGET_NAME].nunique()<50:
            print("TARGET VS cat_cols:")
            unique_target=self.train_df[self.TARGET_NAME].unique()
            for target in unique_target:
                for cat_col in self.cat_cols:
                    unique_value=self.train_df[cat_col].unique()
                    for value in unique_value:
                        tmp_df=self.train_df[self.train_df[cat_col]==value]
                        
                        if len(tmp_df[tmp_df[self.TARGET_NAME]==target])>0.99*len(tmp_df):
                            print(f"when {cat_col}={value},{self.TARGET_NAME}={target}")
                            
                        tmp_df=self.train_df[self.train_df[self.TARGET_NAME]==target]
                        if len(tmp_df[tmp_df[cat_col]==value])>0.99*len(tmp_df):
                            print(f"when {self.TARGET_NAME}={target},{cat_col}={value}")   
            print("-"*50)
            print("TARGET VS num_cols:")
            for num_col in self.num_cols:
                for target in unique_target:
                    tmp_df=self.train_df[self.train_df[self.TARGET_NAME]==target]
                    print(f"when {self.TARGET_NAME}={target},mean_{num_col}={tmp_df[num_col].mean()}")  
                print("-"*50)      
        else:
            print("TARGET VS cat_cols:")
            for target in unique_target:
                for cat_col in self.cat_cols:
                    unique_value=self.train_df[cat_col].unique()
                    for value in unique_value:
                        tmp_df=self.train_df[self.train_df[cat_col]==value]
                        print(f"when {cat_col}={value},mean_{self.TARGET_NAME}={tmp_df[self.TARGET_NAME].mean()}")  
                print("-"*50)   
            
                
    
    
    def tf_idf(self,train, test, column,n,p):
        print(f"tf-idf done with {column}")
        vectorizer=TfidfVectorizer(max_features=n)
        
        vectors_train=vectorizer.fit_transform(train[column])
        vectors_test=vectorizer.transform(test[column])

        svd=TruncatedSVD(p)
        x_pca_train=svd.fit_transform(vectors_train)
        x_pca_test=svd.transform(vectors_test)
        tfidf_df_train=pd.DataFrame(x_pca_train)
        print(len(tfidf_df_train))
        tfidf_df_test=pd.DataFrame(x_pca_test)
        
        
        cols=[(column+"_tfidf_"+str(f)) for f in tfidf_df_train.columns]
        tfidf_df_train.columns=cols
        tfidf_df_test.columns=cols
       
        train=pd.concat([train,tfidf_df_train], axis=1)
        test=pd.concat([test,tfidf_df_test], axis=1)
        train.drop([column],axis=1,inplace=True)
        test.drop([column],axis=1,inplace=True)
        return train, test
    
    def one_hot_encoder(self,total_df):
        print(f"one hot encoder with {self.cat_cols}")
        for col in self.cat_cols:
            if total_df[col].nunique()==2:
                value=total_df[col].values[0]
                total_df[col+"_"+str(value)]=(total_df[col]==value)
                total_df.drop([col],axis=1,inplace=True)
            else:
                values=total_df[col].unique()
                for value in values:
                    total_df[col+"_"+str(value)]=(total_df[col]==value)
                total_df.drop([col],axis=1,inplace=True)
        return total_df          
    
    def make_feats(self):
        total_df=pd.concat((self.train_df,self.test_df),axis=0)
        print(f"len(total_df):{len(total_df)}")
        total_df=self.one_hot_encoder(total_df)
        
#         total_df['Age']=round(total_df['Age'],2)
#         total_df['Height']=round(total_df['Height'],2)
#         total_df['Weight']=round(total_df['Weight'],2)
#         total_df['BMI']=total_df['Weight']/(total_df['Height']**2)
#         cols_to_round = ['FCVC',"NCP","CH2O","FAF","TUE"]
#         for col in cols_to_round:
#             total_df[col] = round(total_df[col])
#             total_df[col] = total_df[col].astype('int')        
        
        
        print("-"*50)
        train_feats=total_df[:len(self.train_df)].reset_index(drop=True)
        test_feats=total_df[len(self.train_df):].reset_index(drop=True)
        print(len(train_feats))
        for col in self.str_cols:
            train_feats,test_feats=self.tf_idf(train_feats, test_feats, column=col,n=int(0.5*train_feats[col].nunique()),p=5)
            print(f"len(train_feats):{len(train_feats)}")
        print("-"*50)
        print(f"Done!! total_features:{len(train_feats.keys().values)-1}")
        return train_feats,test_feats

    
    def submission(self,submission_path=None,test_pred=None):
        if submission_path!=None:
            self.submission_df=pd.read_csv(submission_path)
        else:
            assert 0#assert 0==1?
        self.submission_df[self.TARGET_NAME]=test_pred
        self.submission_df.to_csv("submission.csv",index=None)
        return self.submission_df

# %% [markdown]
# ### Feature engineering

# %%
print("Import data.")
preprocessor=Preprocessor(Config.train_path,Config.origin_path,Config.test_path,Config.TARGET_NAME,Config.seed)
print("-"*50)
print("EDA!!!")
preprocessor.EDA()
print("-"*50)
print("make features.")
train_feats,test_feats=preprocessor.make_feats()
print("-"*50)
print("labels to idx")
labels=['Insufficient_Weight','Normal_Weight', 'Overweight_Level_I','Overweight_Level_II','Obesity_Type_I','Obesity_Type_II', 'Obesity_Type_III'] 
labels2idx={}
idx2labels={}
for idx in range(len(labels)): 
    labels2idx[labels[idx]]=idx 
    idx2labels[idx]=labels[idx]
train_feats['NObeyesdad']=train_feats['NObeyesdad'].apply(lambda x: labels2idx[x])
# Out:
# Import data.
# len(origin_df):2111
# len(self.train_df):22869
# len(self.train_df):22845
# num_cols:['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'].
# cat_cols:['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS'].
# str_cols:[]
# --------------------------------------------------
# EDA!!!
# num_cols VS cat_cols:
# Gender==Male:mean_Age==24.263466649806812
# Gender==Female:mean_Age==23.51581708318059
# --------------------------------------------------
# family_history_with_overweight==yes:mean_Age==24.57657386122972
# family_history_with_overweight==no:mean_Age==20.751128417133124
# --------------------------------------------------
# FAVC==yes:mean_Age==23.99030055041775
# FAVC==no:mean_Age==22.838571207033183
# --------------------------------------------------
# CAEC==Sometimes:mean_Age==24.369394013322964
# CAEC==Frequently:mean_Age==21.071993412112256
# CAEC==no:mean_Age==21.43514510443038
# CAEC==Always:mean_Age==22.242937853107346
# --------------------------------------------------
# SMOKE==no:mean_Age==23.848728647854234
# SMOKE==yes:mean_Age==26.9936025916955
# --------------------------------------------------
# SCC==no:mean_Age==24.007042227903177
# SCC==yes:mean_Age==20.548798081736912
# --------------------------------------------------
# CALC==Sometimes:mean_Age==24.03805904171227
# CALC==no:mean_Age==23.314044780306947
# CALC==Frequently:mean_Age==25.348931300500833
# CALC==Always:mean_Age==21.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_Age==22.307024728747603
# MTRANS==Automobile:mean_Age==31.46528309348371
# MTRANS==Walking:mean_Age==21.00952625478927
# MTRANS==Motorbike:mean_Age==25.763406081632652
# MTRANS==Bike:mean_Age==24.757672
# --------------------------------------------------
#
# Gender==Male:mean_Height==1.7554340853530033
# Gender==Female:mean_Height==1.645830661866108
# --------------------------------------------------
# family_history_with_overweight==yes:mean_Height==1.7098688158625106
# family_history_with_overweight==no:mean_Height==1.6575962820637624
# --------------------------------------------------
# FAVC==yes:mean_Height==1.7038141671948523
# FAVC==no:mean_Height==1.6659392823179793
# --------------------------------------------------
# CAEC==Sometimes:mean_Height==1.7052951636080873
# CAEC==Frequently:mean_Height==1.674345746676514
# CAEC==no:mean_Height==1.6433160443037977
# CAEC==Always:mean_Height==1.6922888870056498
# --------------------------------------------------
# SMOKE==no:mean_Height==1.699792441257315
# SMOKE==yes:mean_Height==1.7531036401384084
# --------------------------------------------------
# SCC==no:mean_Height==1.702126847022029
# SCC==yes:mean_Height==1.6536944546615577
# --------------------------------------------------
# CALC==Sometimes:mean_Height==1.7044209615103978
# CALC==no:mean_Height==1.687104165545784
# CALC==Frequently:mean_Height==1.7212705642737895
# CALC==Always:mean_Height==1.7
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_Height==1.6973562214305287
# MTRANS==Automobile:mean_Height==1.711329919548872
# MTRANS==Walking:mean_Height==1.7235809367816093
# MTRANS==Motorbike:mean_Height==1.7012919999999998
# MTRANS==Bike:mean_Height==1.7338989999999996
# --------------------------------------------------
#
# Gender==Male:mean_Weight==91.03582793607305
# Gender==Female:mean_Weight==84.5712190513398
# --------------------------------------------------
# family_history_with_overweight==yes:mean_Weight==94.11684770170794
# family_history_with_overweight==no:mean_Weight==58.962084854709175
# --------------------------------------------------
# FAVC==yes:mean_Weight==89.71026021733411
# FAVC==no:mean_Weight==68.02505493858345
# --------------------------------------------------
# CAEC==Sometimes:mean_Weight==92.60033718616899
# CAEC==Frequently:mean_Weight==59.29910357939438
# CAEC==no:mean_Weight==69.01063216772152
# CAEC==Always:mean_Weight==69.67726671939737
# --------------------------------------------------
# SMOKE==no:mean_Weight==87.6801222648608
# SMOKE==yes:mean_Weight==96.6630705916955
# --------------------------------------------------
# SCC==no:mean_Weight==88.72338358137068
# SCC==yes:mean_Weight==61.60048101532566
# --------------------------------------------------
# CALC==Sometimes:mean_Weight==92.14212777181079
# CALC==no:mean_Weight==76.25757706811518
# CALC==Frequently:mean_Weight==80.12744983973289
# CALC==Always:mean_Weight==65.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_Weight==88.40429273791176
# MTRANS==Automobile:mean_Weight==87.55696599072681
# MTRANS==Walking:mean_Weight==70.64322157279693
# MTRANS==Motorbike:mean_Weight==73.51352775510205
# MTRANS==Bike:mean_Weight==73.89552256410256
# --------------------------------------------------
#
# Gender==Male:mean_FCVC==2.2783562553565155
# Gender==Female:mean_FCVC==2.6079990645936983
# --------------------------------------------------
# family_history_with_overweight==yes:mean_FCVC==2.455260245623399
# family_history_with_overweight==no:mean_FCVC==2.39085187565101
# --------------------------------------------------
# FAVC==yes:mean_FCVC==2.4443409120354365
# FAVC==no:mean_FCVC==2.4368115329370976
# --------------------------------------------------
# CAEC==Sometimes:mean_FCVC==2.448400458841369
# CAEC==Frequently:mean_FCVC==2.4696495384047266
# CAEC==no:mean_FCVC==2.099083917721519
# CAEC==Always:mean_FCVC==2.3446327683615817
# --------------------------------------------------
# SMOKE==no:mean_FCVC==2.444243136107909
# SMOKE==yes:mean_FCVC==2.3993707301038056
# --------------------------------------------------
# SCC==no:mean_FCVC==2.4409633460724325
# SCC==yes:mean_FCVC==2.520093203065134
# --------------------------------------------------
# CALC==Sometimes:mean_FCVC==2.4954819582907697
# CALC==no:mean_FCVC==2.308628131746853
# CALC==Frequently:mean_FCVC==2.3294415642737896
# CALC==Always:mean_FCVC==2.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_FCVC==2.467941833381748
# MTRANS==Automobile:mean_FCVC==2.3358935696741856
# MTRANS==Walking:mean_FCVC==2.4287859214559386
# MTRANS==Motorbike:mean_FCVC==2.4923668367346936
# MTRANS==Bike:mean_FCVC==2.2564102564102564
# --------------------------------------------------
#
# Gender==Male:mean_NCP==2.786601607481559
# Gender==Female:mean_NCP==2.725257722964127
# --------------------------------------------------
# family_history_with_overweight==yes:mean_NCP==2.770177085877455
# family_history_with_overweight==no:mean_NCP==2.690449977366756
# --------------------------------------------------
# FAVC==yes:mean_NCP==2.7581148030346685
# FAVC==no:mean_NCP==2.7323417285785045
# --------------------------------------------------
# CAEC==Sometimes:mean_NCP==2.748496190150337
# CAEC==Frequently:mean_NCP==2.8613964582717872
# CAEC==no:mean_NCP==2.0726067120253164
# CAEC==Always:mean_NCP==2.890772128060264
# --------------------------------------------------
# SMOKE==no:mean_NCP==2.755354966793758
# SMOKE==yes:mean_NCP==2.7934609238754327
# --------------------------------------------------
# SCC==no:mean_NCP==2.7554262494334147
# SCC==yes:mean_NCP==2.7674111404853132
# --------------------------------------------------
# CALC==Sometimes:mean_NCP==2.8044525349021043
# CALC==no:mean_NCP==2.620932805483704
# CALC==Frequently:mean_NCP==2.730018547579299
# CALC==Always:mean_NCP==1.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_NCP==2.746422272732255
# MTRANS==Automobile:mean_NCP==2.7719417691729324
# MTRANS==Walking:mean_NCP==2.9494226091954023
# MTRANS==Motorbike:mean_NCP==2.8158410408163266
# MTRANS==Bike:mean_NCP==2.8461538461538463
# --------------------------------------------------
#
# Gender==Male:mean_CH2O==2.0619961388303474
# Gender==Female:mean_CH2O==1.9925428949114081
# --------------------------------------------------
# family_history_with_overweight==yes:mean_CH2O==2.0811482185098207
# family_history_with_overweight==no:mean_CH2O==1.781013130688732
# --------------------------------------------------
# FAVC==yes:mean_CH2O==2.0339364718620954
# FAVC==no:mean_CH2O==1.9573130326894501
# --------------------------------------------------
# CAEC==Sometimes:mean_CH2O==2.0601070150855363
# CAEC==Frequently:mean_CH2O==1.7714186310930573
# CAEC==no:mean_CH2O==2.28199367721519
# CAEC==Always:mean_CH2O==1.9830508474576272
# --------------------------------------------------
# SMOKE==no:mean_CH2O==2.0288592532363894
# SMOKE==yes:mean_CH2O==1.894901937716263
# --------------------------------------------------
# SCC==no:mean_CH2O==2.0303280468225906
# SCC==yes:mean_CH2O==1.9380314265644956
# --------------------------------------------------
# CALC==Sometimes:mean_CH2O==2.0596963814301352
# CALC==no:mean_CH2O==1.9333307463355751
# CALC==Frequently:mean_CH2O==2.0424445559265445
# CALC==Always:mean_CH2O==2.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_CH2O==2.044621616716909
# MTRANS==Automobile:mean_CH2O==1.9357406273182958
# MTRANS==Walking:mean_CH2O==2.0895280038314175
# MTRANS==Motorbike:mean_CH2O==2.1027745714285717
# MTRANS==Bike:mean_CH2O==2.2841001025641026
# --------------------------------------------------
#
# Gender==Male:mean_FAF==1.1815671272391992
# Gender==Female:mean_FAF==0.7887882500881558
# --------------------------------------------------
# family_history_with_overweight==yes:mean_FAF==0.9486144976120836
# family_history_with_overweight==no:mean_FAF==1.1485987342419082
# --------------------------------------------------
# FAVC==yes:mean_FAF==0.9657823738720831
# FAVC==no:mean_FAF==1.1785288301139178
# --------------------------------------------------
# CAEC==Sometimes:mean_FAF==0.948211938219803
# CAEC==Frequently:mean_FAF==1.1767139811669127
# CAEC==no:mean_FAF==1.1277408670886075
# CAEC==Always:mean_FAF==1.2408993653483993
# --------------------------------------------------
# SMOKE==no:mean_FAF==0.9837399875093102
# SMOKE==yes:mean_FAF==1.050499197231834
# --------------------------------------------------
# SCC==no:mean_FAF==0.9745792221584624
# SCC==yes:mean_FAF==1.266496330779055
# --------------------------------------------------
# CALC==Sometimes:mean_FAF==0.9149539837808587
# CALC==no:mean_FAF==1.1544674007587514
# CALC==Frequently:mean_FAF==1.2516590183639398
# CALC==Always:mean_FAF==1.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_FAF==0.9660116632096463
# MTRANS==Automobile:mean_FAF==0.9766136027568922
# MTRANS==Walking:mean_FAF==1.647685417624521
# MTRANS==Motorbike:mean_FAF==1.0647054693877551
# MTRANS==Bike:mean_FAF==1.5128205128205128
# --------------------------------------------------
#
# Gender==Male:mean_TUE==0.6544859206621004
# Gender==Female:mean_TUE==0.5876839479794013
# --------------------------------------------------
# family_history_with_overweight==yes:mean_TUE==0.6225470179067036
# family_history_with_overweight==no:mean_TUE==0.6138573202725723
# --------------------------------------------------
# FAVC==yes:mean_TUE==0.6281001923797177
# FAVC==no:mean_TUE==0.5475810054482416
# --------------------------------------------------
# CAEC==Sometimes:mean_TUE==0.6166971146448937
# CAEC==Frequently:mean_TUE==0.6709198031757755
# CAEC==no:mean_TUE==0.3368433164556962
# CAEC==Always:mean_TUE==0.6911487758945386
# --------------------------------------------------
# SMOKE==no:mean_TUE==0.621777711229828
# SMOKE==yes:mean_TUE==0.5590401453287196
# --------------------------------------------------
# SCC==no:mean_TUE==0.6218901876303146
# SCC==yes:mean_TUE==0.5954525376756066
# --------------------------------------------------
# CALC==Sometimes:mean_TUE==0.5831133016843001
# CALC==no:mean_TUE==0.718253703224694
# CALC==Frequently:mean_TUE==0.716771405676127
# CALC==Always:mean_TUE==2.0
# --------------------------------------------------
# MTRANS==Public_Transportation:mean_TUE==0.6662034265826254
# MTRANS==Automobile:mean_TUE==0.38996472518796993
# MTRANS==Walking:mean_TUE==0.8467662509578544
# MTRANS==Motorbike:mean_TUE==0.35771228571428576
# MTRANS==Bike:mean_TUE==0.41025641025641024
# --------------------------------------------------
#
# num_cols VS num_cols:
# TARGET VS cat_cols:
# when NObeyesdad=Overweight_Level_II,SCC=no
# when CALC=Always,NObeyesdad=Normal_Weight
# when NObeyesdad=Insufficient_Weight,SMOKE=no
# when NObeyesdad=Obesity_Type_III,Gender=Female
# when NObeyesdad=Obesity_Type_III,family_history_with_overweight=yes
# when NObeyesdad=Obesity_Type_III,FAVC=yes
# when NObeyesdad=Obesity_Type_III,CAEC=Sometimes
# when NObeyesdad=Obesity_Type_III,SMOKE=no
# when NObeyesdad=Obesity_Type_III,SCC=no
# when NObeyesdad=Obesity_Type_III,CALC=Sometimes
# when NObeyesdad=Obesity_Type_III,MTRANS=Public_Transportation
# when NObeyesdad=Obesity_Type_II,Gender=Male
# when NObeyesdad=Obesity_Type_II,family_history_with_overweight=yes
# when NObeyesdad=Obesity_Type_II,CAEC=Sometimes
# when NObeyesdad=Obesity_Type_II,SCC=no
# when NObeyesdad=Obesity_Type_I,SMOKE=no
# when NObeyesdad=Obesity_Type_I,SCC=no
# --------------------------------------------------
# TARGET VS num_cols:
# when NObeyesdad=Overweight_Level_II,mean_Age=26.13159309815078
# when NObeyesdad=Normal_Weight,mean_Age=20.881652060642093
# when NObeyesdad=Insufficient_Weight,mean_Age=19.378149078494623
# when NObeyesdad=Obesity_Type_III,mean_Age=24.080041814187645
# when NObeyesdad=Obesity_Type_II,mean_Age=27.751251213540197
# when NObeyesdad=Overweight_Level_I,mean_Age=23.095752160562338
# when NObeyesdad=Obesity_Type_I,mean_Age=25.116324718491263
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_Height=1.7059138445945947
# when NObeyesdad=Normal_Weight,mean_Height=1.6712642809155769
# when NObeyesdad=Insufficient_Weight,mean_Height=1.684638634408602
# when NObeyesdad=Obesity_Type_III,mean_Height=1.6768632784897024
# when NObeyesdad=Obesity_Type_II,mean_Height=1.7818002840620595
# when NObeyesdad=Overweight_Level_I,mean_Height=1.6873288853126156
# when NObeyesdad=Obesity_Type_I,mean_Height=1.6935406881324746
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_Weight=82.08548763264581
# when NObeyesdad=Normal_Weight,mean_Weight=61.586235865636155
# when NObeyesdad=Insufficient_Weight,mean_Weight=49.87535939103943
# when NObeyesdad=Obesity_Type_III,mean_Weight=117.93794326910755
# when NObeyesdad=Obesity_Type_II,mean_Weight=115.93805537630465
# when NObeyesdad=Overweight_Level_I,mean_Weight=74.25430311587125
# when NObeyesdad=Obesity_Type_I,mean_Weight=92.42475440478381
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_FCVC=2.228219641536273
# when NObeyesdad=Normal_Weight,mean_FCVC=2.3692839753269914
# when NObeyesdad=Insufficient_Weight,mean_FCVC=2.4792824433691756
# when NObeyesdad=Obesity_Type_III,mean_FCVC=3.0
# when NObeyesdad=Obesity_Type_II,mean_FCVC=2.4223830377997184
# when NObeyesdad=Overweight_Level_I,mean_FCVC=2.2587753892156863
# when NObeyesdad=Obesity_Type_I,mean_FCVC=2.106631594909537
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_NCP=2.5839426806543386
# when NObeyesdad=Normal_Weight,mean_NCP=2.877704582045184
# when NObeyesdad=Insufficient_Weight,mean_NCP=2.9217754501792115
# when NObeyesdad=Obesity_Type_III,mean_NCP=2.9999533384439356
# when NObeyesdad=Obesity_Type_II,mean_NCP=2.793924410437236
# when NObeyesdad=Overweight_Level_I,mean_NCP=2.5335227114317425
# when NObeyesdad=Obesity_Type_I,mean_NCP=2.452109256976388
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_CH2O=2.006600949146515
# when NObeyesdad=Normal_Weight,mean_CH2O=1.8105593605826398
# when NObeyesdad=Insufficient_Weight,mean_CH2O=1.7575311412186378
# when NObeyesdad=Obesity_Type_III,mean_CH2O=2.3231555361556064
# when NObeyesdad=Obesity_Type_II,mean_CH2O=1.976065941325811
# when NObeyesdad=Overweight_Level_I,mean_CH2O=2.063404047354791
# when NObeyesdad=Obesity_Type_I,mean_CH2O=2.127892038945109
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_FAF=1.0502909089615933
# when NObeyesdad=Normal_Weight,mean_FAF=1.1947933213436386
# when NObeyesdad=Insufficient_Weight,mean_FAF=1.2086495383512545
# when NObeyesdad=Obesity_Type_III,mean_FAF=0.5577950883295194
# when NObeyesdad=Obesity_Type_II,mean_FAF=1.0247431430183358
# when NObeyesdad=Overweight_Level_I,mean_FAF=1.1270010003699595
# when NObeyesdad=Obesity_Type_I,mean_FAF=0.9296031166084023
# --------------------------------------------------
# when NObeyesdad=Overweight_Level_II,mean_TUE=0.6979109306543385
# when NObeyesdad=Normal_Weight,mean_TUE=0.6341631605231868
# when NObeyesdad=Insufficient_Weight,mean_TUE=0.8071867229390681
# when NObeyesdad=Obesity_Type_III,mean_TUE=0.5529843402745996
# when NObeyesdad=Obesity_Type_II,mean_TUE=0.42394420267983074
# when NObeyesdad=Overweight_Level_I,mean_TUE=0.5659052301146874
# when NObeyesdad=Obesity_Type_I,mean_TUE=0.732724222017786
# --------------------------------------------------
# --------------------------------------------------
# make features.
# len(total_df):36685
# one hot encoder with ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']
# --------------------------------------------------
# 22845
# --------------------------------------------------
# Done!! total_features:26
# --------------------------------------------------
# labels to idx

# %% [markdown]
# ## Model training

# %%
#model
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier

#KFold
from sklearn.model_selection import StratifiedKFold

def fit_and_predict(model):
    X=train_feats.drop([Config.TARGET_NAME],axis=1).copy()
    y=train_feats[Config.TARGET_NAME].copy()
    test_X=test_feats.drop([Config.TARGET_NAME],axis=1).copy()
    oof_pred_pro=np.zeros((len(X),np.max(y)+1))
    test_pred_pro=np.zeros((Config.num_folds,len(test_X),np.max(y)+1))
    #10
    skf = StratifiedKFold(n_splits=Config.num_folds,random_state=Config.seed, shuffle=True)

    for fold, (train_index, valid_index) in (enumerate(skf.split(X, y.astype(str)))):
        print(f"fold:{fold}")

        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
        
        model.fit(X_train,y_train)
        
        oof_pred_pro[valid_index]=model.predict_proba(X_valid)
        test_pred_pro[fold]=model.predict_proba(test_X)
    
    return oof_pred_pro,test_pred_pro

lgb_params={
    "objective": "multiclass",          # Objective function for the model
    "metric": "multi_logloss",          # Evaluation metric
    "verbosity": -1,                    # Verbosity level (-1 for silent)
    "boosting_type": "gbdt",            # Gradient boosting type
    "random_state": Config.seed,       # Random state for reproducibility
    "num_class": 7,                     # Number of classes in the dataset
    'learning_rate': 0.030962211546832760,  # Learning rate for gradient boosting
    'n_estimators': 500,                # Number of boosting iterations
    'lambda_l1': 0.009667446568254372,  # L1 regularization term
    'lambda_l2': 0.04018641437301800,   # L2 regularization term
    'max_depth': 10,                    # Maximum depth of the trees
    'colsample_bytree': 0.40977129346872643,  # Fraction of features to consider for each tree
    'subsample': 0.9535797422450176,    # Fraction of samples to consider for each boosting iteration
    'min_child_samples': 26             # Minimum number of data needed in a leaf
}

xgb_params = {'grow_policy': 'depthwise', 'n_estimators': 982, 
               'learning_rate': 0.050053726931263504, 'gamma': 0.5354391952653927, 
               'subsample': 0.7060590452456204, 'colsample_bytree': 0.37939433412123275, 
               'max_depth': 23, 'min_child_weight': 21, 'reg_lambda': 9.150224029846654e-08,
               'reg_alpha': 5.671063656994295e-08,
               'booster':'gbtree','objective':'multi:softmax',"verbosity":0
              }
cat_params={'learning_rate': 0.13762007048684638, 'depth': 5, 
          'l2_leaf_reg': 5.285199432056192, 'bagging_temperature': 0.6029582154263095,
         'random_seed': Config.seed,'verbose': False,'iterations':1000}

print("random forest model")
rf_oof_pred_pro,rf_test_pred_pro=fit_and_predict(model=RandomForestClassifier(random_state=Config.seed))
print("lgb model")
lgb_oof_pred_pro,lgb_test_pred_pro=fit_and_predict(model= LGBMClassifier(**lgb_params,verbose=-1))
print("xgb model")
xgb_oof_pred_pro,xgb_test_pred_pro=fit_and_predict(model= XGBClassifier(**xgb_params,seed=Config.seed))
print("cat model")
cat_oof_pred_pro,cat_test_pred_pro=fit_and_predict(model= CatBoostClassifier(**cat_params))
# Out:
# random forest model
# fold:0
# fold:1
# fold:2
# fold:3
# fold:4
# fold:5
# fold:6
# fold:7
# fold:8
# fold:9
# lgb model
# fold:0
# fold:1
# fold:2
# fold:3
# fold:4
# fold:5
# fold:6
# fold:7
# fold:8
# fold:9
# xgb model
# fold:0
# fold:1
# fold:2
# fold:3
# fold:4
# fold:5
# fold:6
# fold:7
# fold:8
# fold:9
# cat model
# fold:0
# fold:1
# fold:2
# fold:3
# fold:4
# fold:5
# fold:6
# fold:7
# fold:8
# fold:9

# %% [markdown]
# ## Blending

# %%
def log_loss(y_true,y_pred):
    eps=10**(-15)
    y_true=np.clip(y_true,eps,1-eps)
    y_pred=np.clip(y_pred,eps,1-eps)
    return -np.mean(np.sum(y_true*np.log(y_pred),axis=-1))
def accuracy(y_true,y_pred):
    return np.mean(y_true==y_pred)
oof_target=train_feats[Config.TARGET_NAME].values
oof_one_hot=np.eye(np.max(oof_target)+1)[oof_target]
step=100
best_w1=1
best_w2=1
best_w3=1
best_accuracy=0
best_log_loss=10
for w1 in range(1,step-1,1):
    for w2 in range(1,step-w1-1,1):
        for w3 in range(1,step-w1-w2-1,1):
            blend_oof_pred_pro=(w1*rf_oof_pred_pro+w2*lgb_oof_pred_pro+w3*xgb_oof_pred_pro+(step-w1-w2-w3)*cat_oof_pred_pro)/step
            current_log_loss=log_loss(oof_one_hot,blend_oof_pred_pro)
            current_accuracy=accuracy(oof_target,np.argmax(blend_oof_pred_pro,axis=1))
            if current_accuracy>best_accuracy:
                best_w1=w1
                best_w2=w2
                best_w3=w3
                best_accuracy=current_accuracy
                best_log_loss=current_log_loss
                print(f"best_w1:{best_w1},best_w2:{best_w2},best_w3:{best_w3},best_accuracy:{best_accuracy},best_log_loss:{best_log_loss}")
            elif (current_accuracy==best_accuracy) and current_log_loss<best_log_loss:
                best_w1=w1
                best_w2=w2
                best_w3=w3
                best_log_loss=current_log_loss
                print(f"best_w1:{best_w1},best_w2:{best_w2},best_w3:{best_w3},best_accuracy:{best_accuracy},best_log_loss:{best_log_loss}")
# Out:
# best_w1:1,best_w2:1,best_w3:1,best_accuracy:0.9126285839352156,best_log_loss:0.2537754383125859
# best_w1:1,best_w2:1,best_w3:2,best_accuracy:0.91275990369884,best_log_loss:0.2534121670623048
# best_w1:1,best_w2:1,best_w3:3,best_accuracy:0.9128912234624644,best_log_loss:0.2530673152261394
# best_w1:1,best_w2:1,best_w3:7,best_accuracy:0.912934996717006,best_log_loss:0.2518122073394826
# best_w1:1,best_w2:1,best_w3:10,best_accuracy:0.9130663164806303,best_log_loss:0.25096921690524454
# best_w1:1,best_w2:1,best_w3:11,best_accuracy:0.9132414094987963,best_log_loss:0.2507036924035631
# best_w1:1,best_w2:1,best_w3:12,best_accuracy:0.9134165025169622,best_log_loss:0.2504452548909837
# best_w1:1,best_w2:1,best_w3:14,best_accuracy:0.9135040490260451,best_log_loss:0.24994842293690928
# best_w1:1,best_w2:1,best_w3:15,best_accuracy:0.9135040490260451,best_log_loss:0.24970950376400358
# best_w1:1,best_w2:1,best_w3:16,best_accuracy:0.9136353687896696,best_log_loss:0.2494766106438351
# best_w1:1,best_w2:1,best_w3:17,best_accuracy:0.913679142044211,best_log_loss:0.24924954193942003
# best_w1:1,best_w2:1,best_w3:18,best_accuracy:0.9138104618078354,best_log_loss:0.24902811402911498
# best_w1:1,best_w2:1,best_w3:19,best_accuracy:0.9138542350623768,best_log_loss:0.24881215889922098
# best_w1:1,best_w2:1,best_w3:20,best_accuracy:0.9138542350623768,best_log_loss:0.24860152218506723
# best_w1:1,best_w2:1,best_w3:21,best_accuracy:0.9138542350623768,best_log_loss:0.24839606155621405
# best_w1:1,best_w2:1,best_w3:22,best_accuracy:0.9139417815714599,best_log_loss:0.24819564537009767
# best_w1:1,best_w2:1,best_w3:23,best_accuracy:0.9140293280805428,best_log_loss:0.24800015153818084
# best_w1:1,best_w2:1,best_w3:24,best_accuracy:0.9142481943532501,best_log_loss:0.2478094665625457
# best_w1:1,best_w2:1,best_w3:25,best_accuracy:0.9144670606259575,best_log_loss:0.24762348471081455
# best_w1:1,best_w2:1,best_w3:26,best_accuracy:0.914598380389582,best_log_loss:0.24744210730453053
# best_w1:1,best_w2:1,best_w3:27,best_accuracy:0.9148172466622894,best_log_loss:0.24726524210150516
# best_w1:1,best_w2:1,best_w3:28,best_accuracy:0.9148172466622894,best_log_loss:0.24709280275667214
# best_w1:1,best_w2:1,best_w3:31,best_accuracy:0.9148172466622894,best_log_loss:0.24660125532855434
# best_w1:1,best_w2:1,best_w3:33,best_accuracy:0.9148610199168308,best_log_loss:0.24629432945692467
# best_w1:1,best_w2:1,best_w3:34,best_accuracy:0.9151236594440797,best_log_loss:0.24614690908497389
# best_w1:1,best_w2:1,best_w3:35,best_accuracy:0.915517618734953,best_log_loss:0.24600344169240315
# best_w1:1,best_w2:1,best_w3:36,best_accuracy:0.9155613919894944,best_log_loss:0.24586387492555556
# best_w1:1,best_w2:1,best_w3:40,best_accuracy:0.9158240315167433,best_log_loss:0.24534367291104495
# best_w1:1,best_w2:1,best_w3:43,best_accuracy:0.9158678047712847,best_log_loss:0.24499234371535267
# best_w1:1,best_w2:1,best_w3:44,best_accuracy:0.9159115780258262,best_log_loss:0.24488244014292096
# best_w1:1,best_w2:1,best_w3:45,best_accuracy:0.9159115780258262,best_log_loss:0.2447760892355439
# best_w1:1,best_w2:1,best_w3:46,best_accuracy:0.9160428977894507,best_log_loss:0.2446732638943394
# best_w1:1,best_w2:1,best_w3:47,best_accuracy:0.9160428977894507,best_log_loss:0.24457393902326213
# best_w1:1,best_w2:1,best_w3:50,best_accuracy:0.9161304442985336,best_log_loss:0.24429674511357122
# best_w1:1,best_w2:1,best_w3:51,best_accuracy:0.916174217553075,best_log_loss:0.2442112092825638
# best_w1:1,best_w2:1,best_w3:56,best_accuracy:0.9162179908076166,best_log_loss:0.24383432167611543
# best_w1:1,best_w2:1,best_w3:57,best_accuracy:0.9163055373166995,best_log_loss:0.24376902767106548
# best_w1:1,best_w2:1,best_w3:58,best_accuracy:0.9163930838257824,best_log_loss:0.24370707779887035
# best_w1:1,best_w2:1,best_w3:59,best_accuracy:0.9168308163711972,best_log_loss:0.2436484681280819
# best_w1:1,best_w2:1,best_w3:60,best_accuracy:0.9168745896257386,best_log_loss:0.24359319642356114
# best_w1:1,best_w2:1,best_w3:61,best_accuracy:0.9169183628802802,best_log_loss:0.24354126216190947
# best_w1:1,best_w2:1,best_w3:62,best_accuracy:0.9170059093893631,best_log_loss:0.24349266655292082
# best_w1:1,best_w2:1,best_w3:63,best_accuracy:0.9170496826439046,best_log_loss:0.24344741256737348
# best_w1:1,best_w2:1,best_w3:64,best_accuracy:0.9170496826439046,best_log_loss:0.24340550497156171
# best_w1:1,best_w2:1,best_w3:68,best_accuracy:0.9170496826439046,best_log_loss:0.2432714992169645
# best_w1:1,best_w2:1,best_w3:69,best_accuracy:0.9170496826439046,best_log_loss:0.243246461287614
# best_w1:1,best_w2:1,best_w3:70,best_accuracy:0.917093455898446,best_log_loss:0.24322483897902186
# best_w1:1,best_w2:1,best_w3:71,best_accuracy:0.917093455898446,best_log_loss:0.24320665128924024
# best_w1:1,best_w2:1,best_w3:72,best_accuracy:0.9172247756620705,best_log_loss:0.24319191961434813
# best_w1:1,best_w2:1,best_w3:73,best_accuracy:0.9173998686802364,best_log_loss:0.24318066788175527
# best_w1:1,best_w2:3,best_w3:71,best_accuracy:0.9174436419347779,best_log_loss:0.24300379892111787
# best_w1:1,best_w2:5,best_w3:82,best_accuracy:0.9174874151893193,best_log_loss:0.24297526491528182
# best_w1:1,best_w2:6,best_w3:82,best_accuracy:0.9174874151893193,best_log_loss:0.2429222954721914
# best_w1:1,best_w2:7,best_w3:81,best_accuracy:0.9174874151893193,best_log_loss:0.24283478800770136
# best_w1:1,best_w2:8,best_w3:79,best_accuracy:0.9175311884438608,best_log_loss:0.24271576621317884
# best_w1:1,best_w2:9,best_w3:79,best_accuracy:0.9175311884438608,best_log_loss:0.24266924918144558
# best_w1:1,best_w2:10,best_w3:77,best_accuracy:0.9175311884438608,best_log_loss:0.24255846350633636
# best_w1:1,best_w2:10,best_w3:82,best_accuracy:0.9176625082074852,best_log_loss:0.2427658030726496
# best_w1:1,best_w2:12,best_w3:79,best_accuracy:0.9177500547165682,best_log_loss:0.24256200244819284
# best_w1:1,best_w2:13,best_w3:81,best_accuracy:0.9178376012256512,best_log_loss:0.24264704009976307
# best_w1:1,best_w2:14,best_w3:80,best_accuracy:0.9178376012256512,best_log_loss:0.24257482658602572
# best_w1:1,best_w2:15,best_w3:79,best_accuracy:0.9178376012256512,best_log_loss:0.2425055491741551
# best_w1:1,best_w2:16,best_w3:79,best_accuracy:0.9178376012256512,best_log_loss:0.24249882051356506
# best_w1:1,best_w2:17,best_w3:78,best_accuracy:0.9178813744801926,best_log_loss:0.24243435228878749
# best_w1:1,best_w2:17,best_w3:79,best_accuracy:0.9179251477347341,best_log_loss:0.24249857661544444
# best_w1:1,best_w2:18,best_w3:77,best_accuracy:0.9179689209892755,best_log_loss:0.24237275442588715
# best_w1:1,best_w2:26,best_w3:52,best_accuracy:0.918012694243817,best_log_loss:0.24175479567915706
# best_w1:1,best_w2:56,best_w3:40,best_accuracy:0.9180564674983585,best_log_loss:0.2421505480614659
# best_w1:2,best_w2:35,best_w3:52,best_accuracy:0.9180564674983585,best_log_loss:0.24162780533826536
# best_w1:4,best_w2:33,best_w3:54,best_accuracy:0.9181002407529,best_log_loss:0.24200588979385362
# best_w1:5,best_w2:33,best_w3:53,best_accuracy:0.9181440140074415,best_log_loss:0.24224666067773584

# %% [markdown]
# ## Submission

# %%
blend_test_pred_pro=(best_w1*rf_test_pred_pro+best_w2*lgb_test_pred_pro+best_w3*xgb_test_pred_pro+(step-best_w1-best_w2-best_w3)*cat_test_pred_pro)/step
test_pred=np.argmax(blend_test_pred_pro.mean(axis=0),axis=1)
test_pred=[idx2labels[int(pred)] for pred in test_pred]
print("submission")
submission_df=preprocessor.submission(submission_path=Config.submission_path,test_pred=test_pred)
submission_df.head()
# Out:
# submission
#       id          NObeyesdad
# 0  20758     Obesity_Type_II
# 1  20759  Overweight_Level_I
# 2  20760    Obesity_Type_III
# 3  20761      Obesity_Type_I
# 4  20762    Obesity_Type_III
